# %%
# !pip install pymongo[srv]

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://admin:admin@cluster0.pcmcr.mongodb.net/anatel?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['anatel', 'admin', 'local']

# %%
db = client.anatel

# %%
db.minas
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.pcmcr.mongodb.net:27017', 'cluster0-shard-00-02.pcmcr.mongodb.net:27017', 'cluster0-shard-00-00.pcmcr.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-13nr8d-shard-0', ssl=True), 'anatel'), 'minas')

# %%
# !python --version
# Out:
# Python 3.8.3

# %%
db.minas.count()
# Out:
# <ipython-input-24-667e98dbe1b8>:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   db.minas.count()
# 509706

# %%
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fb44236464bb20bec22c719'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cartão Telefônico',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5fb44236464bb20bec22c705'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 9},
#  {'_id': ObjectId('5fb44236464bb20bec22c70b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
# ...

# %%
db.minas.find_one(sort=[("QtdeSolic", -1)])
# Out:
# {'_id': ObjectId('5fb442e5464bb20bec24e703'),
#  'DataExtracao': datetime.datetime(2016, 4, 19, 0, 0),
#  'Ano': 2013,
#  'Mes': 12,
#  'CanalEntrada': 'Call Center',
#  'Condicao': 'Nova',
#  'GrupoEconNorm': 'OI',
#  'Tipo': 'Reclamação',
#  'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#  'Modalidade': 'Local',
#  'Motivo': 'Reparo',
#  'UF': 'MG',
#  'QtdeSolic': 4164}

# %%
db.minas.find_one(sort=[("QtdeSolic", 1)])
# Out:
# {'_id': ObjectId('5fb44236464bb20bec22c70b'),
#  'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#  'Ano': 2006,
#  'Mes': 1,
#  'CanalEntrada': 'Call Center',
#  'Condicao': 'Nova',
#  'GrupoEconNorm': 'ALGAR',
#  'Tipo': 'Reclamação',
#  'Servico': 'Móvel Pessoal',
#  'Modalidade': 'Pré-Pago',
#  'Motivo': 'Habilitação',
#  'UF': 'MG',
#  'QtdeSolic': 1}

# %%
list(db.minas.find({'QtdeSolic': 1}))
# Out:
# [{'_id': ObjectId('5fb44236464bb20bec22c70b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb44236464bb20bec22c70f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb44236464bb20bec22c700'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
list(db.minas.find({'QtdeSolic'}).sort({'Servico': 1}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-ca3900dc7a8b> in <module>
# ----> 1 list(db.minas.find({'QtdeSolic'}).sort({'Servico': 1}))
#
# D:\Nova pasta (2)\lib\site-packages\pymongo\collection.py in find(self, *args, **kwargs)
#    1521
#    1522         """
# -> 1523         return Cursor(self, *args, **kwargs)
#    1524
#    1525     def find_raw_batches(self, *args, **kwargs):
#
# D:\Nova pasta (2)\lib\site-packages\pymongo\cursor.py in __init__(self, collection, filter, projection, skip, limit, no_cursor_timeout, cursor_type, sort, allow_partial_results, oplog_replay, modifiers, batch_size, manipulate, collation, hint, max_scan, max_time_ms, max, min, return_key, show_record_id, snapshot, comment, session, allow_disk_use)
#     142             spec = {}
#     143
# --> 144         validate_is_mapping("filter", spec)
# ...

# %%
list(db.minas.find({"Tipo": "Reclamação" }))

# %%
list(db.minas.distinct("Tipo"));
